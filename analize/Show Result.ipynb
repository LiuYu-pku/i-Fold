# %%
import numpy as np  
import os
import re
import pandas as pd

# %% [markdown]
# ## 3660set

# %%
df_ori = pd.read_csv('rmsd_result_oriOF_10_copy.csv')
df_ori = df_ori.iloc[:,[0,1,3,5]]
df_ori
# Out:
#       prot_id  prot_lenth  relaxali_rmsd_ori  unrelaxali_rmsd_ori
# 0     5fdu_1y          10           3.054320             3.027733
# 1      7arh_V          10           2.801638             2.719731
# 2      1lvb_C          10           5.537887             5.445510
# 3      3qhr_J          10           2.961602             2.865940
# 4      5gic_C          10           1.953518             1.963961
# ...       ...         ...                ...                  ...
# 4409   6g2i_A         166           3.425694             2.044887
# 4410   6rw8_A        1319          38.137521            38.084814
# 4411   6gjc_A        1710          44.039302            42.576296
# 4412   7dxk_A         232           2.148830             1.832368
# 4413   4rh7_A        1330           6.725307             6.599427
#
# [4414 rows x 4 columns]

# %%
df_esm = pd.read_csv('rmsd_result_esmwt_10.csv')
df_esm = df_esm.iloc[:,[0,3,5]]
df_esm
# Out:
#       prot_id  relaxali_rmsd_esm  unrelaxali_rmsd_esm
# 0     5fdu_1y           3.119323             3.010197
# 1      7arh_V           2.341292             2.386595
# 2      1lvb_C           2.171236             2.028867
# 3      5gic_C           1.262418             1.267133
# 4      3rwi_C           2.256646             2.211604
# ...       ...                ...                  ...
# 3611   6g2i_A           5.508709             2.605178
# 3612   6rw8_A          24.643748            25.587509
# 3613   6gjc_A          44.868734            44.671536
# 3614   7dxk_A           4.031596             1.486452
# 3615   4rh7_A          18.840953            18.019291
#
# [3616 rows x 3 columns]

# %%
df_esm5 = pd.read_csv('rmsd_result_esm5wt_10.csv')
df_esm5 = df_esm5.iloc[:,[0,3,5]]
df_esm5
# Out:
#       prot_id  relaxali_rmsd_esm5  unrelaxali_rmsd_esm5
# 0     5fdu_1y            2.783859              2.638093
# 1      7arh_V            2.063455              2.075211
# 2      1lvb_C            2.469204              2.346711
# 3      5gic_C            2.788835              2.687113
# 4      3rwi_C            2.328247              2.167946
# ...       ...                 ...                   ...
# 3607   3cmu_A            6.994716              2.998031
# 3608  6qw6_5A            4.631514              4.596935
# 3609   6g2i_A            6.297145              3.986747
# 3610   6rw8_A           42.468389             42.367655
# 3611   6gjc_A           47.138102             46.883200
#
# [3612 rows x 3 columns]

# %%
df_esm10 = pd.read_csv('rmsd_result_esm10wt_10.csv')
df_esm10 = df_esm10.iloc[:,[0,3,5]]
df_esm10
# Out:
#       prot_id  relaxali_rmsd_esm10  unrelaxali_rmsd_esm10
# 0     5fdu_1y             3.062400               2.961385
# 1      7arh_V             2.549705               2.485135
# 2      1lvb_C             1.759300               1.762383
# 3      5gic_C             0.820049               0.810026
# 4      3rwi_C             2.151996               2.038965
# ...       ...                  ...                    ...
# 3613   6g2i_A             2.494649               2.230286
# 3614   6rw8_A             3.297552               3.280100
# 3615   6gjc_A             7.674089               7.567602
# 3616   7dxk_A             1.921914               0.719752
# 3617   4rh7_A             2.553227               2.070093
#
# [3618 rows x 3 columns]

# %%
df_esm20 = pd.read_csv('rmsd_result_esm20wt_10.csv')
df_esm20= df_esm20.iloc[:,[0,3,5]]
df_esm20
# Out:
#       prot_id  relaxali_rmsd_esm20  unrelaxali_rmsd_esm20
# 0     5fdu_1y             3.083651               2.994340
# 1      7arh_V             2.261177               2.285878
# 2      1lvb_C             1.874727               1.975377
# 3      5gic_C             0.806682               0.797614
# 4      3rwi_C             2.494588               2.403520
# ...       ...                  ...                    ...
# 3609   6g2i_A             1.960180               2.052914
# 3610   6rw8_A             4.320324               3.545863
# 3611   6gjc_A             7.220476               7.197920
# 3612   7dxk_A             1.713928               0.699112
# 3613   4rh7_A             1.597087               1.406125
#
# [3614 rows x 3 columns]

# %%
df_esm50 = pd.read_csv('rmsd_result_esm50wt_10.csv')
df_esm50 = df_esm50.iloc[:,[0,3,5]]
df_esm50
# Out:
#       prot_id  relaxali_rmsd_esm50  unrelaxali_rmsd_esm50
# 0     5fdu_1y             2.650551               2.496757
# 1      7arh_V             2.627126               2.511690
# 2      1lvb_C             4.267669               4.212304
# 3      5gic_C             1.332959               1.320433
# 4      3rwi_C             2.185666               2.087610
# ...       ...                  ...                    ...
# 3612   6g2i_A             5.043224               3.900833
# 3613   6rw8_A            53.972100              53.923005
# 3614   6gjc_A            11.226224              11.066378
# 3615   7dxk_A             1.609938               0.926508
# 3616   4rh7_A             6.380263               5.247402
#
# [3617 rows x 3 columns]

# %%
df_total = pd.merge(df_ori,df_esm)
df_total = pd.merge(df_total,df_esm5)
df_total = pd.merge(df_total,df_esm10)
df_total = pd.merge(df_total,df_esm20)
df_total = pd.merge(df_total,df_esm50)
df_total
# Out:
#       prot_id  prot_lenth  relaxali_rmsd_ori  unrelaxali_rmsd_ori  \
# 0     5fdu_1y          10           3.054320             3.027733
# 1      7arh_V          10           2.801638             2.719731
# 2      1lvb_C          10           5.537887             5.445510
# 3      5gic_C          10           1.953518             1.963961
# 4      3rwi_C          10           3.040328             2.982927
# ...       ...         ...                ...                  ...
# 3594   3cmu_A         304           3.438632             3.354513
# 3595  6qw6_5A          27          13.639350            23.543635
# 3596   6g2i_A         166           3.425694             2.044887
# 3597   6rw8_A        1319          38.137521            38.084814
# 3598   6gjc_A        1710          44.039302            42.576296
#
#       relaxali_rmsd_esm  unrelaxali_rmsd_esm  relaxali_rmsd_esm5  \
# 0              3.119323             3.010197            2.783859
# ...

# %%
df_allmsa = pd.read_csv('./testset/msa_count.csv')
df_total = pd.merge(df_total,df_allmsa)
df_total
# Out:
#       prot_id  prot_lenth  relaxali_rmsd_ori  unrelaxali_rmsd_ori  \
# 0     5fdu_1y          10           3.054320             3.027733
# 1      7arh_V          10           2.801638             2.719731
# 2      1lvb_C          10           5.537887             5.445510
# 3      5gic_C          10           1.953518             1.963961
# 4      3rwi_C          10           3.040328             2.982927
# ...       ...         ...                ...                  ...
# 3594   3cmu_A         304           3.438632             3.354513
# 3595  6qw6_5A          27          13.639350            23.543635
# 3596   6g2i_A         166           3.425694             2.044887
# 3597   6rw8_A        1319          38.137521            38.084814
# 3598   6gjc_A        1710          44.039302            42.576296
#
#       relaxali_rmsd_esm  unrelaxali_rmsd_esm  relaxali_rmsd_esm5  \
# 0              3.119323             3.010197            2.783859
# ...

# %%
df_total.describe()
# Out:
#         prot_lenth  relaxali_rmsd_ori  unrelaxali_rmsd_ori  relaxali_rmsd_esm  \
# count  3599.000000        3599.000000          3599.000000        3599.000000
# mean    201.634343           3.213135             3.187147           2.902875
# std     161.621717           4.412056             4.404117           4.233417
# min      10.000000           0.279688             0.325838           0.182621
# 25%      85.000000           1.033249             1.020895           0.912931
# 50%     162.000000           1.812117             1.794400           1.646657
# 75%     278.500000           3.628132             3.532872           3.224921
# max    1710.000000          86.267296            87.266851          86.058597
#
#        unrelaxali_rmsd_esm  relaxali_rmsd_esm5  unrelaxali_rmsd_esm5  \
# count          3599.000000         3599.000000           3599.000000
# mean              2.847179            3.535960              3.477103
# ...

# %%
df_orp = df_total[df_total['MSA_count']<500]
df_orp.describe()
# Out:
#        prot_lenth  relaxali_rmsd_esm  unrelaxali_rmsd_esm  \
# count    400.0000         400.000000           400.000000
# mean     116.0300           4.516083             4.415336
# std      133.3794           6.514700             6.427361
# min       10.0000           0.182621             0.235534
# 25%       25.0000           1.220094             1.195931
# 50%       57.0000           2.541180             2.417589
# 75%      161.0000           5.296880             5.179387
# max     1035.0000          86.058597            84.789596
#
#        relaxali_rmsd_esm10  unrelaxali_rmsd_esm10  relaxali_rmsd_esm100  \
# count           400.000000             400.000000            400.000000
# mean              4.253791               4.154272              4.804554
# std               5.439542               5.416442              6.441063
# min               0.193254               0.240598              0.286701
# 25%               1.184908               1.154396              1.382873
# ...

# %%
df_norp = df_total[df_total['MSA_count']>=500]
df_norp.describe()
# Out:
#         prot_lenth  relaxali_rmsd_esm  unrelaxali_rmsd_esm  \
# count  3210.000000        3210.000000          3210.000000
# mean    212.588785           2.718582             2.666993
# std     162.853653           3.834639             3.840618
# min      10.000000           0.253925             0.264471
# 25%      99.000000           0.893103             0.845027
# 50%     175.000000           1.592619             1.523855
# 75%     288.000000           2.991872             2.927404
# max    1710.000000          66.250938            66.232525
#
#        relaxali_rmsd_esm10  unrelaxali_rmsd_esm10  relaxali_rmsd_esm100  \
# count          3210.000000            3210.000000           3210.000000
# mean              2.447195               2.419381              2.965328
# std               3.100850               3.106511              3.912827
# min               0.226249               0.215416              0.287787
# ...

# %%
df_total.to_csv('rmsd_compare_res.csv', index=False)

# %% [markdown]
# ## new_protein_set

# %%
df_ori = pd.read_csv('rmsd_result_oriOF_250409.csv')
df_ori = df_ori.iloc[:,[0,1,3,5]]
df_ori
# Out:
#     prot_id  prot_lenth  relaxali_rmsd_ori  unrelaxali_rmsd_ori
# 0    8vs6_E          10           4.175697             3.950822
# 1    8j47_D          29           9.282417             9.246547
# 2    8ihu_A          72          17.843655            17.824403
# 3    8jxg_D          72           1.365632             1.401971
# 4    8r7o_A          75           2.999650             2.977984
# ..      ...         ...                ...                  ...
# 164  8qmp_A         913           5.072290             5.114323
# 165  8jtj_A        1175          16.066319            16.068607
# 166  8exx_A        1088          12.331741            12.460160
# 167  8iyq_A         717          10.425558            10.312286
# 168  8k58_C        1340           3.029745             3.038595
#
# [169 rows x 4 columns]

# %%
df_esm = pd.read_csv('rmsd_result_esmwt_250409.csv')
df_esm = df_esm.iloc[:,[0,3,5]]
df_esm
# Out:
#     prot_id  relaxali_rmsd_esm  unrelaxali_rmsd_esm
# 0    8vs6_E           5.182129             4.918466
# 1    8j47_D           9.452406             9.393421
# 2    8ihu_A          17.864561            17.850097
# 3    8jxg_D           1.535887             1.551344
# 4    8r7o_A           2.913461             2.872585
# ..      ...                ...                  ...
# 163  8qmp_A           4.430096             4.458291
# 164  8jtj_A          16.174816            16.174197
# 165  8exx_A           8.078082             8.017570
# 166  8iyq_A          10.576871            10.510230
# 167  8k58_C           3.464300             3.468834
#
# [168 rows x 3 columns]

# %%
df_esm5 = pd.read_csv('rmsd_result_esmwt5_250409.csv')
df_esm5 = df_esm5.iloc[:,[0,3,5]]
df_esm5
# Out:
#     prot_id  relaxali_rmsd_esm5  unrelaxali_rmsd_esm5
# 0    8vs6_E            5.602477              5.358939
# 1    8j47_D            8.940256              8.880130
# 2    8ihu_A           17.864061             17.841781
# 3    8jxg_D            1.372119              1.384687
# 4    8r7o_A            2.851029              2.826739
# ..      ...                 ...                   ...
# 164  8qmp_A            4.143879              4.179290
# 165  8jtj_A           19.376926             19.201443
# 166  8exx_A           13.148237             13.117967
# 167  8iyq_A           14.615972             14.151210
# 168  8k58_C           10.314762             10.028261
#
# [169 rows x 3 columns]

# %%
df_esm10 = pd.read_csv('rmsd_result_esmwt10_250409.csv')
df_esm10 = df_esm10.iloc[:,[0,3,5]]
df_esm10
# Out:
#     prot_id  relaxali_rmsd_esm10  unrelaxali_rmsd_esm10
# 0    8vs6_E             5.048271               4.851521
# 1    8j47_D             9.239295               9.215408
# 2    8ihu_A            17.879741              17.877823
# 3    8jxg_D             1.480316               1.493098
# 4    8r7o_A             3.214349               3.200474
# ..      ...                  ...                    ...
# 164  8qmp_A             4.276406               4.306077
# 165  8jtj_A            16.282957              16.253558
# 166  8exx_A             8.277567               8.040460
# 167  8iyq_A             7.538394               7.475963
# 168  8k58_C             3.373680               3.375090
#
# [169 rows x 3 columns]

# %%
df_esm20 = pd.read_csv('rmsd_result_esmwt20_250409.csv')
df_esm20 = df_esm20.iloc[:,[0,3,5]]
df_esm20
# Out:
#     prot_id  relaxali_rmsd_esm20  unrelaxali_rmsd_esm20
# 0    8vs6_E             5.559213               5.325926
# 1    8j47_D             9.339868               9.312057
# 2    8ihu_A            17.875013              17.865863
# 3    8jxg_D             1.524081               1.523414
# 4    8r7o_A             3.159152               3.139490
# ..      ...                  ...                    ...
# 163  8qmp_A             4.263485               4.280557
# 164  8jtj_A            16.259010              16.221787
# 165  8exx_A             8.053618               7.955276
# 166  8iyq_A             6.417531               6.292747
# 167  8k58_C             2.970179               2.974057
#
# [168 rows x 3 columns]

# %%
df_esm50 = pd.read_csv('rmsd_result_esmwt50_250409.csv')
df_esm50 = df_esm50.iloc[:,[0,3,5]]
df_esm50
# Out:
#     prot_id  relaxali_rmsd_esm50  unrelaxali_rmsd_esm50
# 0    8vs6_E             5.328724               5.050937
# 1    8j47_D            10.172420              10.165976
# 2    8ihu_A            17.897578              17.930110
# 3    8jxg_D             1.706350               1.711272
# 4    8r7o_A             3.315784               3.290733
# ..      ...                  ...                    ...
# 162  8qmp_A             3.263205               3.281986
# 163  8jtj_A            15.963716              15.959855
# 164  8exx_A            13.178534              13.207176
# 165  8iyq_A            11.333876              10.870494
# 166  8k58_C             3.344650               3.354629
#
# [167 rows x 3 columns]

# %%
df_total = pd.merge(df_ori,df_esm)
df_total = pd.merge(df_total,df_esm5)
df_total = pd.merge(df_total,df_esm10)
df_total = pd.merge(df_total,df_esm20)
df_total = pd.merge(df_total,df_esm50)
df_total
# Out:
#     prot_id  prot_lenth  relaxali_rmsd_ori  unrelaxali_rmsd_ori  \
# 0    8vs6_E          10           4.175697             3.950822
# 1    8j47_D          29           9.282417             9.246547
# 2    8ihu_A          72          17.843655            17.824403
# 3    8jxg_D          72           1.365632             1.401971
# 4    8r7o_A          75           2.999650             2.977984
# ..      ...         ...                ...                  ...
# 162  8qmp_A         913           5.072290             5.114323
# 163  8jtj_A        1175          16.066319            16.068607
# 164  8exx_A        1088          12.331741            12.460160
# 165  8iyq_A         717          10.425558            10.312286
# 166  8k58_C        1340           3.029745             3.038595
#
#      relaxali_rmsd_esm  unrelaxali_rmsd_esm  relaxali_rmsd_esm5  \
# 0             5.182129             4.918466            5.602477
# 1             9.452406             9.393421            8.940256
# ...

# %%
df_total.describe()
# Out:
#         prot_lenth  relaxali_rmsd_ori  unrelaxali_rmsd_ori  relaxali_rmsd_esm  \
# count   167.000000         167.000000           167.000000         167.000000
# mean    338.059880           5.334933             5.308514           5.059807
# std     226.371661           6.644147             6.589853           6.431349
# min      10.000000           0.394618             0.454896           0.354110
# 25%     179.000000           1.273649             1.274651           1.211568
# 50%     272.000000           2.622219             2.606962           2.187850
# 75%     436.500000           6.291015             6.294219           5.946458
# max    1340.000000          43.867632            43.766436          42.464467
#
#        unrelaxali_rmsd_esm  relaxali_rmsd_esm5  unrelaxali_rmsd_esm5  \
# count           167.000000          167.000000            167.000000
# mean              5.025442            6.283117              6.186019
# ...

# %%
df_msa = pd.read_csv('/home/liuyu/codes/ifold/my_works/testset/msa_count_250409.csv')
df_total = pd.merge(df_total,df_msa)
df_total
# Out:
#     prot_id  prot_lenth  relaxali_rmsd_ori  unrelaxali_rmsd_ori  \
# 0    8vs6_E          10           4.175697             3.950822
# 1    8j47_D          29           9.282417             9.246547
# 2    8ihu_A          72          17.843655            17.824403
# 3    8jxg_D          72           1.365632             1.401971
# 4    8r7o_A          75           2.999650             2.977984
# ..      ...         ...                ...                  ...
# 162  8qmp_A         913           5.072290             5.114323
# 163  8jtj_A        1175          16.066319            16.068607
# 164  8exx_A        1088          12.331741            12.460160
# 165  8iyq_A         717          10.425558            10.312286
# 166  8k58_C        1340           3.029745             3.038595
#
#      relaxali_rmsd_esm  unrelaxali_rmsd_esm  relaxali_rmsd_esm5  \
# 0             5.182129             4.918466            5.602477
# 1             9.452406             9.393421            8.940256
# ...

# %%
df_orphan = df_total[df_total['MSA_count']<500]
df_orphan
# Out:
#     prot_id  prot_lenth  relaxali_rmsd_ori  unrelaxali_rmsd_ori  \
# 0    8vs6_E          10           4.175697             3.950822
# 1    8j47_D          29           9.282417             9.246547
# 3    8jxg_D          72           1.365632             1.401971
# 12   8wke_A         104           1.331934             1.333734
# 13   9f2g_A         108           0.897346             0.931501
# 22   9evy_A         128           1.710972             1.723268
# 24   9f5j_A         130           4.190061             4.176286
# 33   8bwd_A         164          16.094929            16.112380
# 42   8k4u_A         184           1.873104             1.902647
# 46   8c0y_A         190           0.927279             0.989713
# 47   8xk2_A         193           1.251135             1.263526
# 85   8qu7_E         277           1.501311             1.448348
# 91   8tqt_A         306           0.721512             0.758728
# 94   8yx4_A         311           0.941642             0.877264
# ...

# %%
human_xray = '7GA8,7GUS,7GY4,7HG0,7MU6,7SZW,8BM8,8BOP,8BWD,8BZE,8C61,8CN6,8CPR,8EPH,8F7M,8FPQ,8FPX,8GL7,8JJI,8JN8,8JNZ,8K33,8K4Q,8K62,8QQ6,8QQA,8QQB,8QQE,8QSU,8QT0,8QTW,8QU7,8QUS,8QVF,8QVY,8QWG,8QWK,8QZ5,8R0H,8R0Z,8R21,8R2F,8R25,8R3U,8R3W,8R40,8R5E,8R74,8R7O,8R7W'.split(',')
human_elec = '8C0Y,8CBK,8CMT,8E6V,8GHK,8I3V,8IDA,8IHU,8IKG,8IRJ,8IZQ,8JEF,8J47,8JJP,8JKH,8JRN,8JWH,8JXS,8K0F,8K10,8K1B,8K3Z,8KB4,8KDR,8KEX,8KGV,8KHR,8UVE,8UW8,8UWC,8UXV,8V2J,8V25,8V3Q,8V4F,8V4K,8V5D,8V8S,8V91,8VBY,8VDG,8VE1,8VIC,8VIF,8VKJ,8VS6,8VSU,8VSJ'.split(',')
nonhum_xray = '8UZE,9DN4,8R6O,8XX0,9IMP,8HYC,8JI9,8K7N,8PC9,8QUQ,8R2Y,8VVA,9DRD,8JOI,8TQT,8WFM,8WKE,8XK2,8YX4,9BRV,9CSY,9EVY,9F2G,9F5J,9C83,9D2D,9DHL,9EGR,9FZD,9GNL,9ILD,9JTI,9K8M,8IYV,8KDU,8P2T,8QEA,8UAX,8V4I,8XNI,9F6C,9C6E,9IT8,9JWD,7G2H'.split(',')
nonhum_elec = '7EXA,8CNK,8EXX,8GHL,8HAT,8HAU,8HQS,8I96,8HX0,8IAR,8IYQ,8JEV,8JFY,8JGM,8JR8,8JSI,8JTJ,8JXD,8JXG,8JXO,8JYL,8JZL,8K0A,8K04,8K0X,8K1A,8K1M,8K25,8K29,8K3H,8K4U,8K52,8K58,8K7U,8K87,8K88,8QC1,8QHS,8QMP,8QOG,8QPF,8QPG,8QSR,8QT6,8QTN,8QYC,8R3Z,8RC6'.split(',')

# %%
id_lst = list(df_total['prot_id'])
organ = []
method = []
for item in id_lst:
    id = item.split('_')[0].upper()
    if id in human_xray:
        organ.append('Human')
        method.append('X-ray Diffraction')
    elif id in human_elec:
        organ.append('Human')
        method.append('Electron Microscopy')
    elif id in nonhum_xray:
        organ.append('Non-human')
        method.append('X-ray Diffraction')
    elif id in nonhum_elec:
        organ.append('Non-human')
        method.append('Electron Microscopy')
    else:
        organ.append('unknown')
        method.append('unknown')

# %%
df_total['Organism'] = organ
df_total['Method'] = method
df_total
# Out:
#     prot_id  prot_lenth  relaxali_rmsd_ori  unrelaxali_rmsd_ori  \
# 0    8vs6_E          10           4.175697             3.950822
# 1    8j47_D          29           9.282417             9.246547
# 2    8ihu_A          72          17.843655            17.824403
# 3    8jxg_D          72           1.365632             1.401971
# 4    8r7o_A          75           2.999650             2.977984
# ..      ...         ...                ...                  ...
# 162  8qmp_A         913           5.072290             5.114323
# 163  8jtj_A        1175          16.066319            16.068607
# 164  8exx_A        1088          12.331741            12.460160
# 165  8iyq_A         717          10.425558            10.312286
# 166  8k58_C        1340           3.029745             3.038595
#
#      relaxali_rmsd_esm  unrelaxali_rmsd_esm  relaxali_rmsd_esm5  \
# 0             5.182129             4.918466            5.602477
# 1             9.452406             9.393421            8.940256
# ...

# %%
df_total.to_csv('rmsd_compare_res_250409.csv', index=False)

# %%
df_total.describe()
# Out:
#         prot_lenth  relaxali_rmsd_ori  unrelaxali_rmsd_ori  relaxali_rmsd_esm  \
# count   167.000000         167.000000           167.000000         167.000000
# mean    338.059880           5.334933             5.308514           5.059807
# std     226.371661           6.644147             6.589853           6.431349
# min      10.000000           0.394618             0.454896           0.354110
# 25%     179.000000           1.273649             1.274651           1.211568
# 50%     272.000000           2.622219             2.606962           2.187850
# 75%     436.500000           6.291015             6.294219           5.946458
# max    1340.000000          43.867632            43.766436          42.464467
#
#        unrelaxali_rmsd_esm  relaxali_rmsd_esm5  unrelaxali_rmsd_esm5  \
# count           167.000000          167.000000            167.000000
# mean              5.025442            6.283117              6.186019
# ...
